# %%
from __future__ import division, print_function
import numpy as np
from sklearn import datasets, svm 
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ------------------------------------------------------------
# ModuleNotFoundError        Traceback (most recent call last)
# <ipython-input-1-12fb14f21a94> in <module>()
#       3 import numpy as np
#       4 from sklearn import datasets, svm
# ----> 5 from sklearn.cross_validation import train_test_split
#       6 import matplotlib.pyplot as plt
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'sklearn.cross_validation'

# %% [markdown]
# # 1. Support Vector Classification
#
# # 1.1 Load the Iris dataset

# %%
iris = datasets.load_iris()
X = iris.data[:,:2]
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-2-0a9e0a93c65f> in <module>()
#       3 y = iris.target
#       4
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# # 1.2 Use Support Vector Machine with different kinds of kernels and evaluate performance

# %%
def evaluate_on_test_data(model=None):
    predictions = model.predict(X_test)
    correct_classifications = 0
    for i in range(len(y_test)):
        if predictions[i] == y_test[i]:
            correct_classifications += 1
    accuracy = 100*correct_classifications/len(y_test) #Accuracy as a percentage
    return accuracy

# %%
kernels = ('linear','poly','rbf')
accuracies = []
for index, kernel in enumerate(kernels):
    model = svm.SVC(kernel=kernel)
    model.fit(X_train, y_train)
    acc = evaluate_on_test_data(model)
    accuracies.append(acc)
    print("{} % accuracy obtained with kernel = {}".format(acc, kernel))
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-4-d4b64094adbd> in <module>()
#       3 for index, kernel in enumerate(kernels):
#       4     model = svm.SVC(kernel=kernel)
# ----> 5     model.fit(X_train, y_train)
#       6     acc = evaluate_on_test_data(model)
#       7     accuracies.append(acc)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# # 1.3 Visualize the decision boundaries

# %%
#Train SVMs with different kernels
svc = svm.SVC(kernel='linear').fit(X_train, y_train)
rbf_svc = svm.SVC(kernel='rbf', gamma=0.7).fit(X_train, y_train)
poly_svc = svm.SVC(kernel='poly', degree=3).fit(X_train, y_train)

#Create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

#Define title for the plots
titles = ['SVC with linear kernel',
          'SVC with RBF kernel',
          'SVC with polynomial (degree 3) kernel']


for i, clf in enumerate((svc, rbf_svc, poly_svc)):
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, m_max]x[y_min, y_max].
    plt.figure(i)

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.ocean)
    plt.xlabel('Sepal length')
    plt.ylabel('Sepal width')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(titles[i])

plt.show()
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-5-987fe06c7fe6> in <module>()
#       1
#       2 #Train SVMs with different kernels
# ----> 3 svc = svm.SVC(kernel='linear').fit(X_train, y_train)
#       4 rbf_svc = svm.SVC(kernel='rbf', gamma=0.7).fit(X_train, y_train)
#       5 poly_svc = svm.SVC(kernel='poly', degree=3).fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# # 1.4 Check the support vectors

# %%
#Checking the support vectors of the polynomial kernel (for example)
print("The support vectors are:\n", poly_svc.support_vectors_)
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-6-7258f6c65a07> in <module>()
#       1 #Checking the support vectors of the polynomial kernel (for example)
# ----> 2 print("The support vectors are:\n", poly_svc.support_vectors_)
#
# NameError: name 'poly_svc' is not defined

# %% [markdown]
# # 2. Support Vector Regression
#
# # 2.1 Load data from the Boston dataset

# %%
boston = datasets.load_boston()
X = boston.data
y = boston.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-7-4deebffc616f> in <module>()
#       3 y = boston.target
#       4
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# # 2.2 Use Support Vector Machine with different kinds of kernels and evaluate performance

# %%
def evaluate_on_test_data(model=None):
    predictions = model.predict(X_test)
    sum_of_squared_error = 0
    for i in range(len(y_test)):
        err = (predictions[i]-y_test[i]) **2
        sum_of_squared_error += err
    mean_squared_error = sum_of_squared_error/len(y_test)
    RMSE = np.sqrt(mean_squared_error) 
    return RMSE

# %%
kernels = ('linear','rbf')
RMSE_vec = []
for index, kernel in enumerate(kernels):
    model = svm.SVR(kernel=kernel)
    model.fit(X_train, y_train)
    RMSE = evaluate_on_test_data(model)
    RMSE_vec.append(RMSE)
    print("RMSE={} obtained with kernel = {}".format(RMSE, kernel))
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-9-6b89fd4b71e0> in <module>()
#       3 for index, kernel in enumerate(kernels):
#       4     model = svm.SVR(kernel=kernel)
# ----> 5     model.fit(X_train, y_train)
#       6     RMSE = evaluate_on_test_data(model)
#       7     RMSE_vec.append(RMSE)
#
# NameError: name 'X_train' is not defined
